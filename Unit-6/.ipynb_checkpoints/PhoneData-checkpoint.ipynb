# %%
import pandas as pd

# %%
data = pd.read_csv('phone_data.csv')

# %%
data.head()
# Out:
#    index            date  duration  item    month   network network_type
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile

# %%
#How many rows is the dataset
data.shape
# Out:
# (830, 7)

# %%
#how many types of items are there
phone_data['item'].value_counts()
# Out:
# call    388
# sms     292
# data    150
# Name: item, dtype: int64

# %%
#what was the longest phone call 
data[data['item'] == 'call'] #data frame of only calls given
# Out:
#      index            date  duration  item    month   network network_type
# 1        1  15/10/14 06:58      13.0  call  2014-11  Vodafone       mobile
# 2        2  15/10/14 14:46      23.0  call  2014-11    Meteor       mobile
# 3        3  15/10/14 14:48       4.0  call  2014-11     Tesco       mobile
# 4        4  15/10/14 17:27       4.0  call  2014-11     Tesco       mobile
# 5        5  15/10/14 18:55       4.0  call  2014-11     Tesco       mobile
# ..     ...             ...       ...   ...      ...       ...          ...
# 807    807  03/03/15 10:12     745.0  call  2015-03  Vodafone       mobile
# 808    808  03/03/15 10:27      57.0  call  2015-03  Vodafone       mobile
# 809    809  03/03/15 14:34    1325.0  call  2015-03  Vodafone       mobile
# 810    810  03/03/15 18:36     768.0  call  2015-03     Three       mobile
# 816    816  04/03/15 12:29   10528.0  call  2015-03  landline     landline
#
# [388 rows x 7 columns]

# %%
data[data['item'] == 'call']['duration'].max()
# Out:
# 10528.0

# %%
#how many entries are there for each month
data.head(20)
# Out:
#     index            date  duration  item    month    network network_type
# 0       0  15/10/14 06:58    34.429  data  2014-11       data         data
# 1       1  15/10/14 06:58    13.000  call  2014-11   Vodafone       mobile
# 2       2  15/10/14 14:46    23.000  call  2014-11     Meteor       mobile
# 3       3  15/10/14 14:48     4.000  call  2014-11      Tesco       mobile
# 4       4  15/10/14 17:27     4.000  call  2014-11      Tesco       mobile
# 5       5  15/10/14 18:55     4.000  call  2014-11      Tesco       mobile
# 6       6  16/10/14 06:58    34.429  data  2014-11       data         data
# 7       7  16/10/14 15:01   602.000  call  2014-11      Three       mobile
# 8       8  16/10/14 15:12  1050.000  call  2014-11      Three       mobile
# 9       9  16/10/14 15:30    19.000  call  2014-11  voicemail    voicemail
# 10     10  16/10/14 16:21  1183.000  call  2014-11      Three       mobile
# ...

# %%
data['month'].value_counts() #WILL GIVE THE NUMBER OF Entries per each month and can give the total in the data (if categorical data value count will give you vale)
# Out:
# 2014-11    230
# 2015-01    205
# 2014-12    157
# 2015-02    137
# 2015-03    101
# Name: month, dtype: int64

# %%
#number of non-null unique network entries 
data['network'].nunique()
# Out:
# 9

# %%
data['network'].unique() #shows list of networks and all the data is there if not network says data
# Out:
# array(['data', 'Vodafone', 'Meteor', 'Tesco', 'Three', 'voicemail',
#        'landline', 'special', 'world'], dtype=object)

# %%
#How many entries per network
data['network'].value_counts()
# Out:
# Vodafone     215
# Three        215
# data         150
# Meteor        87
# Tesco         84
# landline      42
# voicemail     27
# world          7
# special        3
# Name: network, dtype: int64
